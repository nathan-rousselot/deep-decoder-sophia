# %% [markdown]
# # Inpainting with the deep decoder

# %%
from __future__ import print_function
import matplotlib.pyplot as plt
#%matplotlib notebook

import os

import warnings
warnings.filterwarnings('ignore')

from include import *
from PIL import Image
import PIL

import numpy as np
import torch
import torch.optim
from Sophia import SophiaG
from Sophia import DecoupledSophia
from torch.autograd import Variable

import time



GPU = True
if GPU == True:
    torch.backends.cudnn.enabled = True
    torch.backends.cudnn.benchmark = True
    dtype = torch.cuda.FloatTensor
    os.environ['CUDA_VISIBLE_DEVICES'] = '0'
    print("num GPUs",torch.cuda.device_count())
else:
    dtype = torch.FloatTensor
# Out:
# num GPUs 1

# %% [markdown]
# ## Load image

# %%
path = './test_data/'
img_name = "poster"

img_path = path + img_name + ".png"
img_pil = Image.open(img_path)
img_np = pil_to_np(img_pil)
img_clean_var = np_to_var(img_np).type(dtype)

output_depth = img_np.shape[0]
img_mask_pil = Image.open('./test_data/mask.png')
mask_np = pil_to_np(img_mask_pil)
mask_np = np.array([mask_np[0,:,:] / np.max(mask_np) ] * output_depth)
mask_var = np_to_var(mask_np).type(dtype)

# %% [markdown]
# ## Generate inpainted image

# %%
img_noisy_var = img_clean_var * mask_var
img_noisy_np = var_to_np(img_noisy_var)

# %% [markdown]
# ## Recover image

# %%
num_channels = [256]*5
net = decodernw(output_depth,num_channels_up=num_channels,upsample_first = True).type(dtype)

print("number of parameters: ", num_param(net))


rnd = 500
numit = 2000
rn = 0.005
sgd_time = time.time()
mse_n_sgd, mse_t_sgd, ni, net = fit( num_channels=num_channels,
                        reg_noise_std=rn,
                        reg_noise_decayevery = rnd,
                        num_iter=numit,
                        LR=0.025,
                        OPTIMIZER="SGD",
                        img_noisy_var=img_noisy_var,
                        net=net,
                        img_clean_var=img_clean_var,
                        mask_var = mask_var,
                        find_best=True,
                        )
sgd_time = time.time()-sgd_time
# Out:
# number of parameters:  397056
# shape:  [1, 256, 16, 16]
# optimize with SGD 0.025
# Iteration 01990    Train loss 0.003213  Actual loss 0.004046 Actual loss orig 0.003865  Noise Energy 0.045447

# %%
num_channels = [256]*5
net = decodernw(output_depth,num_channels_up=num_channels,upsample_first = True).type(dtype)

print("number of parameters: ", num_param(net))

rnd = 500
numit = 100
rn = 0.005

adam_time = time.time()

mse_n_adam, mse_t_adam, ni_adam, net_adam = fit( num_channels=num_channels,
                        reg_noise_std=rn,
                        reg_noise_decayevery = rnd,
                        num_iter=numit,
                        LR=0.0025,
                        OPTIMIZER="adam",
                        img_noisy_var=img_noisy_var,
                        net=net,
                        img_clean_var=img_clean_var,
                        mask_var = mask_var,
                        find_best=True,
                        )

adam_time = time.time()-adam_time
# Out:
# number of parameters:  397312
# shape:  [1, 256, 16, 16]
# optimize with adam 0.0025
# Iteration 00990    Train loss 0.001572  Actual loss 0.002056 Actual loss orig 0.001806  Noise Energy 0.050934

# %%
num_channels = [256]*5
net = decodernw(output_depth,num_channels_up=num_channels,upsample_first = True).type(dtype)

print("number of parameters: ", num_param(net))

rnd = 500
numit = 2000
rn = 0.005

mse_n_lbfgs, mse_t_lbfgs, ni, net = fit( num_channels=num_channels,
                        reg_noise_std=rn,
                        reg_noise_decayevery = rnd,
                        num_iter=numit,
                        LR=0.0025,
                        OPTIMIZER="LBFGS",
                        img_noisy_var=img_noisy_var,
                        net=net,
                        img_clean_var=img_clean_var,
                        mask_var = mask_var,
                        find_best=True,
                        )
# Out:
# number of parameters:  397056
# shape:  [1, 256, 16, 16]
# optimize with LBFGS 0.0025
# Iteration 00800    Train loss 0.002283  Actual loss 0.002995 Actual loss orig 0.002766  Noise Energy 0.045447
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [12], line 10
#       7 numit = 2000
#       8 rn = 0.005
# ---> 10 mse_n_lbfgs, mse_t_lbfgs, ni, net = fit( num_channels=num_channels,
#      11                         reg_noise_std=rn,
#      12                         reg_noise_decayevery = rnd,
#      13                         num_iter=numit,
#      14                         LR=0.0025,
#      15                         OPTIMIZER="LBFGS",
#      16                         img_noisy_var=img_noisy_var,
#      17                         net=net,
#      18                         img_clean_var=img_clean_var,
#      19                         mask_var = mask_var,
#      20                         find_best=True,
#      21                         )
#
# File /notebooks/supplement_deep_decoder-master/include/fit.py:138, in fit(net, img_noisy_var, num_channels, img_clean_var, num_iter, LR, OPTIMIZER, opt_input, reg_noise_std, reg_noise_decayevery, mask_var, apply_f, lr_decay_epoch, net_input, net_input_gen, find_best, weight_decay)
#     128     return loss
#     131 #if OPTIMIZER == 'LBFGS':
#     132 #    if i < 100:
#     133 #        optimizer = torch.optim.Adam(p, lr=LR)
#     134 #    else:
#     135 #        optimizer = torch.optim.LBFGS(p, lr=LR)
# --> 138 loss = optimizer.step(closure)
#     140 if find_best:
#     141     # if training loss improves by at least one percent, we found a new best net
#     142     if best_mse > 1.005*loss.data:
#
# File /usr/local/lib/python3.9/dist-packages/torch/optim/optimizer.py:113, in Optimizer._hook_for_profile.<locals>.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     111 profile_name = "Optimizer.step#{}.step".format(obj.__class__.__name__)
#     112 with torch.autograd.profiler.record_function(profile_name):
# --> 113     return func(*args, **kwargs)
#
# File /usr/local/lib/python3.9/dist-packages/torch/autograd/grad_mode.py:27, in _DecoratorContextManager.__call__.<locals>.decorate_context(*args, **kwargs)
#      24 @functools.wraps(func)
#      25 def decorate_context(*args, **kwargs):
#      26     with self.clone():
# ---> 27         return func(*args, **kwargs)
#
# File /usr/local/lib/python3.9/dist-packages/torch/optim/lbfgs.py:437, in LBFGS.step(self, closure)
#     432 if n_iter != max_iter:
#     433     # re-evaluate function only if not in last iteration
#     434     # the reason we do this: in a stochastic setting,
#     435     # no use to re-evaluate that function here
#     436     with torch.enable_grad():
# --> 437         loss = float(closure())
#     438     flat_grad = self._gather_flat_grad()
#     439     opt_cond = flat_grad.abs().max() <= tolerance_grad
#
# File /usr/local/lib/python3.9/dist-packages/torch/autograd/grad_mode.py:27, in _DecoratorContextManager.__call__.<locals>.decorate_context(*args, **kwargs)
#      24 @functools.wraps(func)
#      25 def decorate_context(*args, **kwargs):
#      26     with self.clone():
# ---> 27         return func(*args, **kwargs)
#
# File /notebooks/supplement_deep_decoder-master/include/fit.py:118, in fit.<locals>.closure()
#     115     loss = mse(out, img_noisy_var)
#     117 loss.backward()
# --> 118 mse_wrt_noisy[i] = loss.data.cpu().numpy()
#     121 # the actual loss
#     122 true_loss = mse(Variable(out.data, requires_grad=False), img_clean_var)
#
# KeyboardInterrupt:

# %%
num_channels = [256]*5
net = decodernw(output_depth,num_channels_up=num_channels,upsample_first = True).type(dtype)

print("number of parameters: ", num_param(net))

rnd = 500
numit = 400
rn = 0.005
sophia_time = time.time()
mse_n_sophiag, mse_t_sophiag, ni_sophiag, net_sophiag = fit( num_channels=num_channels,
                        reg_noise_std=rn,
                        reg_noise_decayevery = rnd,
                        num_iter=numit,
                        LR=0.0015,
                        OPTIMIZER="SophiaG",
                        img_noisy_var=img_noisy_var,
                        net=net,
                        img_clean_var=img_clean_var,
                        mask_var = mask_var,
                        find_best=True,
                        )
sophia_time = time.time()-sophia_time
# Out:
# number of parameters:  397312
# shape:  [1, 256, 16, 16]
# optimize with SophiaG
# Iteration 00390    Train loss 0.004131  Actual loss 0.005206 Actual loss orig 0.004629  Noise Energy 0.050934

# %%
num_channels = [256]*5
net = decodernw(output_depth,num_channels_up=num_channels,upsample_first = True).type(dtype)

print("number of parameters: ", num_param(net))

rnd = 500
numit = 400
rn = 0.005
sophia_time = time.time()
mse_n_sophiah, mse_t_sophiah, ni_sophiah, net_sophiah = fit( num_channels=num_channels,
                        reg_noise_std=rn,
                        reg_noise_decayevery = rnd,
                        num_iter=numit,
                        LR=0.0015,
                        OPTIMIZER="SophiaH",
                        img_noisy_var=img_noisy_var,
                        net=net,
                        img_clean_var=img_clean_var,
                        mask_var = mask_var,
                        find_best=True,
                        )
sophia_time = time.time()-sophia_time
# Out:
# number of parameters:  397312
# shape:  [1, 256, 16, 16]
# optimize with SophiaH
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [4], line 10
#       8 rn = 0.005
#       9 sophia_time = time.time()
# ---> 10 mse_n_sophiah, mse_t_sophiah, ni_sophiah, net_sophiah = fit( num_channels=num_channels,
#      11                         reg_noise_std=rn,
#      12                         reg_noise_decayevery = rnd,
#      13                         num_iter=numit,
#      14                         LR=0.0015,
#      15                         OPTIMIZER="SophiaH",
#      16                         img_noisy_var=img_noisy_var,
#      17                         net=net,
#      18                         img_clean_var=img_clean_var,
#      19                         mask_var = mask_var,
#      20                         find_best=True,
#      21                         )
#      22 sophia_time = time.time()-sophia_time
#
# File /notebooks/supplement_deep_decoder-master/include/fit.py:89, in fit(net, img_noisy_var, num_channels, img_clean_var, num_iter, LR, OPTIMIZER, opt_input, reg_noise_std, reg_noise_decayevery, mask_var, apply_f, lr_decay_epoch, net_input, net_input_gen, find_best, weight_decay)
#      87 elif OPTIMIZER == 'SophiaH':
#      88     print("optimize with SophiaH")
# ---> 89     optimizer = Sophia(p, lr=LR, weight_decay=weight_decay,estimator="Hutchinson")
#      90 elif OPTIMIZER == 'OMD':
#      91     print("optimize with Optimistic Mirror Descent")
#
# NameError: name 'Sophia' is not defined

# %%
num_channels = [256]*5
net = decodernw(output_depth,num_channels_up=num_channels,upsample_first = True).type(dtype)

print("number of parameters: ", num_param(net))

rnd = 500
numit = 1000
rn = 0.005
omd_time = time.time()
mse_n_omd, mse_t_omd, ni_omd, net_omd = fit( num_channels=num_channels,
                        reg_noise_std=rn,
                        reg_noise_decayevery = rnd,
                        num_iter=numit,
                        LR=0.0025,
                        OPTIMIZER="OMD",
                        img_noisy_var=img_noisy_var,
                        net=net,
                        img_clean_var=img_clean_var,
                        mask_var = mask_var,
                        find_best=True,
                        )
omd_time = time.time()-omd_time
# Out:
# number of parameters:  397056
# shape:  [1, 256, 16, 16]
# optimize with Optimistic Mirror Descent
# Iteration 01990    Train loss 0.001227  Actual loss 0.001863 Actual loss orig 0.001819  Noise Energy 0.045447

# %%
def myimgshow(plt,img):
    plt.imshow(np.clip(img.transpose(1, 2, 0),0,1))
    
fig = plt.figure(figsize = (15,15)) 
    
ax1 = fig.add_subplot(221)
myimgshow(ax1,img_np) 
ax1.set_title('Original image')
ax1.axis('off')
    
ax2 = fig.add_subplot(222)
myimgshow(ax2,img_noisy_np)
ax2.set_title( "Noisy observation, PSNR: %.2f" % psnr(img_np,img_noisy_np) )
ax2.axis('off')

out_img_np_adam = net_adam( ni_adam.type(dtype) ).data.cpu().numpy()[0]
ax3 = fig.add_subplot(223)
myimgshow(ax3,out_img_np_adam)
ax3.set_title( "Deep-Decoder Adam recovered image, SNR: %.2f" % psnr(img_np,out_img_np_adam) ) 
ax3.axis('off')  

out_img_np_sophiag = net_sophiag( ni_sophiag.type(dtype) ).data.cpu().numpy()[0]
ax3 = fig.add_subplot(224)
myimgshow(ax3,out_img_np_sophiag)
ax3.set_title( "Deep-Decoder SophiaG recovered image, SNR: %.2f" % psnr(img_np,out_img_np_sophia) ) 
ax3.axis('off')
# Out:
# (-0.5, 511.5, 511.5, -0.5)

# %% [markdown]
# ## Role of the choice of Optimizer

# %% [markdown]
# ### Computational Cost

# %%
print('Pour ', numit, ' itérations:\n- Stochastic Gradient Descent : ',sgd_time,\
      ' secondes\n- Adam: ', adam_time, ' secondes\n- Sophia : ', \
     sophia_time, ' secondes\n- Optimistic Mirror Descent : ',omd_time, 'secondes')
# Out:
# Pour  10000  itérations:
# - Stochastic Gradient Descent :  123.38307666778564  secondes
# - Adam:  602.0812871456146  secondes
# - Sophia :  606.770117521286  secondes
# - Optimistic Mirror Descent :  117.81899785995483 secondes

# %% [markdown]
# ### Convergence Analysis

# %%
fig = plt.figure(figsize = (15,5)) 
#fig.settitle('Convergence Analysis')

ax1 = fig.add_subplot(121)
#ax1.semilogy(mse_t_sgd,label="SGD")
ax1.semilogy(mse_t_adam,label="Adam")
#ax1.semilogy(mse_t_lbfgs)
ax1.semilogy(mse_t_sophiag,label="SophiaG")
#ax1.semilogy(mse_t_sophiah,label="SophiaH")

#ax1.semilogy(mse_t_omd,label="OMD")
ax1.legend(['Adam','SophiaG'])
#ax1.legend(['SGD','Adam','Sophia','OMD'])

ax2 = fig.add_subplot(122)
ax1.set_xlabel('Iterations')
ax1.set_ylabel('Truth Mean Square Error')
#ax2.semilogy(mse_n_sgd,label="SGD")
ax2.semilogy(mse_n_adam,label="Adam")
#ax2.semilogy(mse_n_lbfgs)
ax2.semilogy(mse_n_sophiag,label="SophiaG")
#ax2.semilogy(mse_n_sophiah,label="SophiaH")

#ax2.semilogy(mse_n_omd,label="OMD")
ax2.legend(['Adam','SophiaG'])
#ax2.legend(['SGD','Adam','Sophia','OMD'])

ax2.set_xlabel('Iterations')
ax2.set_ylabel('Net Mean Square Error')
# Out:
# Text(0, 0.5, 'Net Mean Square Error')

# %%
# Out:
# (25,)
